# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import classification_report
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_dir = '/content/drive/MyDrive/workshop5(AI)/FruitinAmazon/train'
class_dirs = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]

# %%
class_dirs = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]
image_paths = []
for class_dir in class_dirs:
    class_path = os.path.join(train_dir, class_dir)
    images = os.listdir(class_path)
    if images:
        image_paths.append(os.path.join(class_path, random.choice(images)))
num_classes = len(image_paths)
fig, axes = plt.subplots(nrows=2, ncols=(num_classes + 1) // 2, figsize=(12, 6))

for ax, img_path, label in zip(axes.flatten(), image_paths, class_dirs):
    img = mpimg.imread(img_path)
    ax.imshow(img)
    ax.set_title(label)
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
from PIL import Image
corrupted_images = []
for class_dir in class_dirs:
    class_path = os.path.join(train_dir, class_dir)
    for img_name in os.listdir(class_path):
        img_path = os.path.join(class_path, img_name)

        try:
            with Image.open(img_path) as img:
                img.verify()

        except (IOError, SyntaxError):
            corrupted_images.append(img_path)
            os.remove(img_path)
            print(f"Removed corrupted image: {img_path}")
if not corrupted_images:
    print("No Corrupted Images Found.")
else:
    print(f"Total corrupted images removed: {len(corrupted_images)}")
# Out:
# No Corrupted Images Found.

# %%
def load_and_preprocess_data(train_dir, img_height, img_width, batch_size, validation_split):
    rescale = tf.keras.layers.Rescaling(1./255)

    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        train_dir,
        labels='inferred',
        label_mode='int',
        image_size=(img_height, img_width),
        interpolation='nearest',
        batch_size=batch_size,
        shuffle=True,
        validation_split=validation_split,
        subset='training',
        seed=123
    )

    train_ds = train_ds.map(lambda x, y: (rescale(x), y))

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        train_dir,
        labels='inferred',
        label_mode='int',
        image_size=(img_height, img_width),
        interpolation='nearest',
        batch_size=batch_size,
        shuffle=False,
        validation_split=validation_split,
        subset='validation',
        seed=123
    )

    val_ds = val_ds.map(lambda x, y: (rescale(x), y))

    return train_ds, val_ds
img_height = 128
img_width = 128
batch_size = 32
validation_split = 0.2
train_ds, val_ds = load_and_preprocess_data(train_dir, img_height, img_width, batch_size, validation_split)
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.

# %%
num_classes = 6
model = keras.Sequential([
    # Convolutional Layer 1
    layers.Conv2D(32, (3, 3), padding="same", strides=1, activation="relu", input_shape=(128, 128, 3)),
    layers.MaxPooling2D(pool_size=(2, 2), strides=2),

    # Convolutional Layer 2
    layers.Conv2D(32, (3, 3), padding="same", strides=1, activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2), strides=2),

    # Flatten Layer
    layers.Flatten(),

    # Fully Connected Layers
    layers.Dense(64, activation="relu"),
    layers.Dense(128, activation="relu"),

    # Output Layer
    layers.Dense(num_classes, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     2,097,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,116,454 (8.07 MB)
#  Trainable params: 2,116,454 (8.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras import layers, models

def create_cnn_model(num_classes, input_shape):
    model = models.Sequential([
        layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

num_classes = len(os.listdir(train_dir))
input_shape = (img_height, img_width, 3)
model = create_cnn_model(num_classes, input_shape)

# %%
def create_cnn_model(num_classes, input_shape):
    model = models.Sequential([
        layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model
num_classes = len(os.listdir(train_dir))
input_shape = (img_height, img_width, 3)
model = create_cnn_model(num_classes, input_shape)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

callbacks = [
    ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss'),
    EarlyStopping(patience=10, restore_best_weights=True)
]
history = model.fit(train_ds, epochs=250, validation_data=val_ds, callbacks=callbacks)
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.2205 - loss: 2.3221 - val_accuracy: 0.1667 - val_loss: 3.2032
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.4232 - loss: 1.5280 - val_accuracy: 0.6111 - val_loss: 1.4400
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.5729 - loss: 1.1863 - val_accuracy: 0.8333 - val_loss: 0.9753
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7166 - loss: 0.9378 - val_accuracy: 0.6111 - val_loss: 1.2345
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 623ms/step - accuracy: 0.8385 - loss: 0.6727 - val_accuracy: 0.8333 - val_loss: 0.5583
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 715ms/step - accuracy: 0.9232 - loss: 0.4116 - val_accuracy: 0.8889 - val_loss: 0.4589
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 797ms/step - accuracy: 0.9418 - loss: 0.2580 - val_accuracy: 0.8333 - val_loss: 0.5642
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 591ms/step - accuracy: 0.9813 - loss: 0.1237 - val_accuracy: 0.8889 - val_loss: 0.3776
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 599ms/step - accuracy: 0.9813 - loss: 0.0760 - val_accuracy: 0.9444 - val_loss: 0.1605
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 539ms/step - accuracy: 1.0000 - loss: 0.0334 - val_accuracy: 0.9444 - val_loss: 0.2344
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 537ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 0.8333 - val_loss: 0.3433
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 704ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8333 - val_loss: 0.5071
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 750ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.8333 - val_loss: 0.5151
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 623ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8333 - val_loss: 0.3396
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 549ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8889 - val_loss: 0.2507
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 472ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9444 - val_loss: 0.2283
# Epoch 17/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 585ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9444 - val_loss: 0.2294
# Epoch 18/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 1.0000 - loss: 8.3517e-04 - val_accuracy: 0.8889 - val_loss: 0.2475
# Epoch 19/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 463ms/step - accuracy: 1.0000 - loss: 8.1729e-04 - val_accuracy: 0.8889 - val_loss: 0.2575

# %%
rescale = tf.keras.layers.Rescaling(1./255)
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/MyDrive/workshop5(AI)/FruitinAmazon/test',
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False
)
test_ds = test_ds.map(lambda x, y: (rescale(x), y))
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Found 30 files belonging to 6 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.7333 - loss: 0.6856
# Test accuracy: 0.7333

# %%
history = model.fit(
    train_ds,  # Training dataset (defined in Task 2)
    validation_data=val_ds,  # Validation dataset (defined in Task 2)
    epochs=250,  # Number of epochs
    batch_size=16,  # Batch size
    callbacks=callbacks,  # Callbacks for checkpointing and early stopping
    verbose=1  # Show progress during training
)
print("Training finished.")
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 541ms/step - accuracy: 1.0000 - loss: 0.0303 - val_accuracy: 0.8889 - val_loss: 0.2271
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 546ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.8333 - val_loss: 0.3331
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 695ms/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 0.8333 - val_loss: 0.4340
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 1.0000 - loss: 0.0243 - val_accuracy: 0.8333 - val_loss: 0.3164
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 496ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.8333 - val_loss: 0.2550
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 475ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9444 - val_loss: 0.1941
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 468ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.9444 - val_loss: 0.1711
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 818ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.8333 - val_loss: 0.2563
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 742ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8333 - val_loss: 0.3077
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 479ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8333 - val_loss: 0.2292
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 542ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8889 - val_loss: 0.1927
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 548ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9444 - val_loss: 0.2435
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 679ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8333 - val_loss: 0.3632
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 846ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8333 - val_loss: 0.3541
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 475ms/step - accuracy: 1.0000 - loss: 7.5649e-04 - val_accuracy: 0.8333 - val_loss: 0.3045
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 533ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8333 - val_loss: 0.2732
# Epoch 17/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 495ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8889 - val_loss: 0.2245
# Training finished.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

test_dir = '/content/drive/MyDrive/workshop5(AI)/FruitinAmazon/test'
test_datagen = ImageDataGenerator(rescale=1./255)
test_ds = test_datagen.flow_from_directory(
    test_dir,
    target_size=(128, 128),
    batch_size=16,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 30 images belonging to 6 classes.

# %%
test_loss, test_accuracy = model.evaluate(test_ds, verbose=2)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 1/1 - 0s - 369ms/step - accuracy: 0.7333 - loss: 0.6856
# Test Loss: 0.6855698823928833
# Test Accuracy: 0.7333333492279053

# %%
rescale = tf.keras.layers.Rescaling(1./255)
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/MyDrive/workshop5(AI)/FruitinAmazon/test',
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False
)
test_ds = test_ds.map(lambda x, y: (rescale(x), y))
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Found 30 files belonging to 6 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.7333 - loss: 0.6856
# Test accuracy: 0.7333

# %%
test_loss, test_accuracy = model.evaluate(test_ds, verbose=2)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 1/1 - 0s - 268ms/step - accuracy: 0.7333 - loss: 0.6856
# Test Loss: 0.6855698823928833
# Test Accuracy: 0.7333333492279053
